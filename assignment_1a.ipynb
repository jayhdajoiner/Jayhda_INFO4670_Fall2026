# %% [markdown]
# <a href="https://colab.research.google.com/github/jayhdajoiner/Jayhda_INFO4670_Fall2026/blob/main/assignment_1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first python code for NLP

# %%
name = "Jayhda"
course = "INFO 4670"

print("My name is", name)
print("I am enrolled in", course)
print("My first Google Colab notebook is working!")
# Out:
# My name is Jayhda
# I am enrolled in INFO 4670
# My first Google Colab notebook is working!
